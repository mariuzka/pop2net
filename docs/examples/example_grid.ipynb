# %% [markdown]
# # Grid graph using networkx

# %%
import networkx as nx
import popy


class MyAgent(popy.Agent):
    pass

class SmallWorld(popy.MagicLocation):
    nxgraph = nx.grid_2d_graph(4,4)

model = popy.Model()
creator = popy.Creator(model)
inspector = popy.NetworkInspector(model)

for _ in range(16):
    popy.Agent(model)

creator.create_locations(location_classes=[SmallWorld])
# Out:
# LocationList (24 objects)

# %%
g = nx.grid_2d_graph(5,5)

# %%
inspector.plot_bipartite_network()
# Out:
#   <div id="abec4ea3-cbf8-43a7-9aab-2613c785717c" data-root-id="p3277" style="display: contents;"></div>

# %%
inspector.plot_agent_network()
# Out:
#   <div id="a9f9403a-2ee8-43c2-a4ed-df270a167649" data-root-id="p3679" style="display: contents;"></div>
