# %%
import agentpy as ap

import pop2net as p2n

# %% [markdown]
# ## No framework

# %%
class MyLocationDesigner(p2n.LocationDesigner):
    pass


env = p2n.Environment()
creator = p2n.Creator(env=env)
inspector = p2n.NetworkInspector(env=env)

creator.create_actors(n=10)
creator.create_locations(location_designers=[MyLocationDesigner])
inspector.plot_bipartite_network()
# Out:
#   <div id="f2e19ed3-e09a-4e49-91f8-3a7210fe88c2" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ## Pop2net + Agentpy

# %%
class MyLocationDesigner(p2n.LocationDesigner):
    pass


model = ap.Model()
env = p2n.Environment(model=model, framework="agentpy")
creator = p2n.Creator(env=env)
inspector = p2n.NetworkInspector(env=env)

creator.create_actors(n=10)
creator.create_locations(location_designers=[MyLocationDesigner])
inspector.plot_bipartite_network()
# Out:
#   <div id="a2b3e0c9-84c1-4b4c-b14d-4edf9f0e5aaa" data-root-id="p1066" style="display: contents;"></div>
